# %%
import numpy as np 
import pandas as pd 
import math 
from sklearn import datasets, model_selection, naive_bayes
from sklearn.naive_bayes import MultinomialNB

# %%
Precipitation = pd.Series({'10/22/21': 1.263 ,'10/23/21': 0.5, '10/24/21': 3.5, '10/25/21': 13.6, '10/26/21': 127, '10/27/21': 6.85, '10/28/21': 0.04})
RelativeHumidity = pd.Series({'10/22/21': 15 ,'10/23/21': 45, '10/24/21': 70, '10/25/21': 5, '10/26/21': 2, '10/27/21': 95, '10/28/21': 26})
SoilWaterContent = pd.Series({'10/22/21': 0.02 ,'10/23/21': 0.5, '10/24/21': 0.3, '10/25/21': 0.2, '10/26/21': 0.079, '10/27/21': 0.175, '10/28/21': 0.25})
SolarRadiation = pd.Series({'10/22/21': 15 ,'10/23/21': 25, '10/24/21': 30, '10/25/21': 21, '10/26/21': 23, '10/27/21': 27, '10/28/21': 26})
Temperature = pd.Series({'10/22/21': 15 ,'10/23/21': 35, '10/24/21': 25, '10/25/21': 31, '10/26/21': 19, '10/27/21': 21, '10/28/21': 39})
WindSpeed = pd.Series({'10/22/21': 3,'10/23/21': 4, '10/24/21': 7,'10/25/21': 2, '10/26/21': 5, '10/27/21': 6, '10/28/21': 5})
    
df = pd.DataFrame({'Mean Precipitation': Precipitation,
                      'Mean Relative Humidity': RelativeHumidity,
                      'Mean Soil Water Content': SoilWaterContent,
                      'Mean Solar Radiation': SolarRadiation,
                      'Mean Temperature': Temperature,
                      'Mean Wind Speeds': WindSpeed})
df.index.name = 'Date (mm/dd/yy)'
df.to_csv('predict_weather.csv')
df
# Out:
#                  Mean Precipitation  Mean Relative Humidity  \
# Date (mm/dd/yy)
# 10/22/21                      1.263                      15
# 10/23/21                      0.500                      45
# 10/24/21                      3.500                      70
# 10/25/21                     13.600                       5
# 10/26/21                    127.000                       2
# 10/27/21                      6.850                      95
# 10/28/21                      0.040                      26
#
#                  Mean Soil Water Content  Mean Solar Radiation  \
# Date (mm/dd/yy)
# 10/22/21                           0.020                    15
# 10/23/21                           0.500                    25
# 10/24/21                           0.300                    30
# 10/25/21                           0.200                    21
# 10/26/21                           0.079                    23
# 10/27/21                           0.175                    27
# ...
